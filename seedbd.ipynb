# %%
import pandas as pd
import os
import re

# %%
atividades = pd.read_csv('./Atividade.csv', sep=',')
usuarios = pd.read_csv('./user.csv')
grupos = pd.read_csv('./grupos.csv')
user_grupos = pd.read_csv('./user_grupos.csv')
user_role = pd.read_csv('./user_roles.csv')
presenca = pd.read_csv('./presenca.csv')

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://postgres:Leer2025@localhost:5432/PJASisTarefas")

# %%
import pandas as pd
import ast

grupos = pd.read_csv("./grupos.csv")

# Converter colunas string "[2,4,5]" para lista [2,4,5]
grupos["dias_empresa"] = grupos["dias_empresa"].apply(ast.literal_eval)
grupos["dias_instituicao"] = grupos["dias_instituicao"].apply(ast.literal_eval)

# Inserir no Postgres
grupos.to_sql(
    "grupos",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 7

# %%
presenca.to_sql(
  "presenca",
  engine,
  if_exists="append",
  index=False
)
# Out:
# 447

# %%
atividades.to_sql(
  "Atividade",
  engine,
  if_exists="append",
  index=False
)
# Out:
# 83

# %%
tarefas = pd.read_csv('./Tarefas.csv', sep=';')
tarefas.info()

# %%
def converter_data_em_numero(data: str) -> int:
    partes = data.split(":")
    if len(partes) != 2:
        raise ValueError('Formato inválido. Use "HH:MM".')
    
    horas, minutos = map(int, partes)
    return horas * 60 + minutos

# %%
tarefas['h_inicio'] = tarefas['h_inicio'].apply(converter_data_em_numero)
tarefas['h_termino'] = tarefas['h_termino'].apply(converter_data_em_numero)

# %%
tarefas.to_sql(
  "tarefas",
  engine,
  if_exists="append",
  index=False
)
# Out:
# 823
